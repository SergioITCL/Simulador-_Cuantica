# %%
from math import sqrt
import numpy as np
H1 = np.array([[1/sqrt(2), 1/sqrt(2)], [1/sqrt(2), -1/sqrt(2)]])
n=5
V=np.random.rand(2**n,2)

# %%
import numpy as np
import h5py
from math import sqrt
import time
inicio=time.time()
# Calcular el producto tensorial
#tensor_result = tensor_product(vectors)
tensor_result = np.random.rand(2**28)
with h5py.File('data2.h5', 'w') as f:
    f.create_dataset('dataset_name', data=tensor_result)
print(tensor_result)
# Out:
# /home/sergio/.local/lib/python3.10/site-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# [0.10313253 0.96699602 0.96835561 ... 0.43483462 0.68809558 0.88504938]

# %%
import matplotlib.pyplot as plt

# Datos
variables = [31, 30, 29, 27, 25, 23, 21]
tiempos = [4490, 2218.67, 2127.7734, 698, 821, 508.72, 423.958]

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(variables, tiempos, marker='o', color='b', linestyle='-')

# Etiquetas y título
plt.xlabel('Número de variables', fontsize=16)
plt.ylabel('Tiempo (s)', fontsize=16)
plt.title('Tiempo en función del número de variables', fontsize=18)
# Mostrar la gráfica
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 27.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 18.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 KB 30.2 MB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import QuantumCircuit
from qiskit.circuit.library import UnitaryGate
from qiskit.quantum_info import Operator, random_unitary
 
UU = random_unitary(4, seed=12345)
rand_U = UnitaryGate(UU)
 
qc = QuantumCircuit(2)
qc.append(rand_U, range(2))
qc.swap(0, 1)
qc.draw("mpl", style="iqp")
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
 
backend = FakeSherbrooke()
 
pass_manager = generate_preset_pass_manager(
    optimization_level=1, backend=backend, seed_transpiler=12345
)
qc_t1_exact = pass_manager.run(qc)
qc_t1_exact.draw("mpl", idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qiskit import QuantumCircuit
#       2 from qiskit.circuit.library import UnitaryGate
#       3 from qiskit.quantum_info import Operator, random_unitary
#
# ModuleNotFoundError: No module named 'qiskit'
